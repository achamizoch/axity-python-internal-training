# %% [markdown]
# # Python & DB

# %% [markdown]
# ### Installar el adaptador de base de datos PostgreSQL

# %%
# %%!
# pip install psycopg2-binary
# Out:
# ['Collecting psycopg2-binary',
#  '  Downloading psycopg2_binary-2.8.6-cp38-cp38-macosx_10_9_x86_64.macosx_10_9_intel.macosx_10_10_intel.macosx_10_10_x86_64.whl (1.5 MB)',
#  'Installing collected packages: psycopg2-binary',
#  'Successfully installed psycopg2-binary-2.8.6']

# %% [markdown]
# ### Importar módulos

# %%
import configparser
import psycopg2
import pandas as pd

# %%
config = configparser.ConfigParser()
config.read('data_files/dwh.cfg')
# Out:
# ['data_files/dwh.cfg']

# %% [markdown]
# ### Cargar datos desde archivo JSON

# %%
df = pd.read_json("data_files/2018-11-01-events.json", orient="records", lines=True)

# %%
df.head(5)
# Out:
#     artist       auth firstName gender  itemInSession lastName     length  \
# 0     None  Logged In    Walter      M              0     Frye        NaN
# 1     None  Logged In    Kaylee      F              0  Summers        NaN
# 2  Des'ree  Logged In    Kaylee      F              1  Summers  246.30812
# 3     None  Logged In    Kaylee      F              2  Summers        NaN
# 4  Mr Oizo  Logged In    Kaylee      F              3  Summers  144.03873
#
#   level                           location method      page   registration  \
# 0  free  San Francisco-Oakland-Hayward, CA    GET      Home  1540919166796
# 1  free        Phoenix-Mesa-Scottsdale, AZ    GET      Home  1540344794796
# 2  free        Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong  1540344794796
# 3  free        Phoenix-Mesa-Scottsdale, AZ    GET   Upgrade  1540344794796
# 4  free        Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong  1540344794796
#
#    sessionId          song  status             ts  \
# 0         38          None     200  1541105830796
# 1        139          None     200  1541106106796
# 2        139  You Gotta Be     200  1541106106796
# 3        139          None     200  1541106132796
# 4        139       Flat 55     200  1541106352796
#
#                                            userAgent  userId
# 0  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      39
# 1  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 2  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 3  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 4  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8

# %% [markdown]
# ### Limpiar datos

# %%
df = df[df["artist"].notnull()]
df.reset_index(drop=True, inplace=True)

# %%
#filter = df["artist"] == 'Mr Oizo'
#df = df[filter]

# %%
df["play_date"] = pd.to_datetime(df['ts'], unit="ms").dt.date

# %%
location = df["location"].str.split(",", n = 1, expand = True)

# %%
df["location"] = location[0]
df["state"] = location[1]

# %%
df.rename(columns={'firstName':'first_name',
                  'lastName':'last_name',
                  'userId':'user_id'}, 
        inplace=True)

# %%
df["artist"]= df["artist"].str.replace("'", "''")

# %%
df
# Out:
#                         artist       auth first_name gender  itemInSession  \
# 0                     Des''ree  Logged In     Kaylee      F              1
# 1                      Mr Oizo  Logged In     Kaylee      F              3
# 2                   Tamba Trio  Logged In     Kaylee      F              4
# 3               The Mars Volta  Logged In     Kaylee      F              5
# 4            Infected Mushroom  Logged In     Kaylee      F              6
# 5   Blue October / Imogen Heap  Logged In     Kaylee      F              7
# 6                    Girl Talk  Logged In     Kaylee      F              8
# 7              Black Eyed Peas  Logged In     Sylvie      F              0
# 8                 Fall Out Boy  Logged In       Ryan      M              1
# 9                       M.I.A.  Logged In       Ryan      M              2
# 10                    Survivor  Logged In     Jayden      M              0
#
#    last_name     length level                         location method  \
# 0    Summers  246.30812  free          Phoenix-Mesa-Scottsdale    PUT
# 1    Summers  144.03873  free          Phoenix-Mesa-Scottsdale    PUT
# 2    Summers  177.18812  free          Phoenix-Mesa-Scottsdale    PUT
# 3    Summers  380.42077  free          Phoenix-Mesa-Scottsdale    PUT
# 4    Summers  440.26730  free          Phoenix-Mesa-Scottsdale    PUT
# 5    Summers  241.39710  free          Phoenix-Mesa-Scottsdale    PUT
# 6    Summers  160.15628  free          Phoenix-Mesa-Scottsdale    PUT
# 7       Cruz  214.93506  free  Washington-Arlington-Alexandria    PUT
# 8      Smith  200.72444  free   San Jose-Sunnyvale-Santa Clara    PUT
# 9      Smith  233.71710  free   San Jose-Sunnyvale-Santa Clara    PUT
# 10       Fox  245.36771  free             New Orleans-Metairie    PUT
#
#         page   registration  sessionId  \
# 0   NextSong  1540344794796        139
# 1   NextSong  1540344794796        139
# 2   NextSong  1540344794796        139
# 3   NextSong  1540344794796        139
# 4   NextSong  1540344794796        139
# 5   NextSong  1540344794796        139
# 6   NextSong  1540344794796        139
# 7   NextSong  1540266185796          9
# 8   NextSong  1541016707796        169
# 9   NextSong  1541016707796        169
# 10  NextSong  1541033612796        100
#
#                                                 song  status             ts  \
# 0                                       You Gotta Be     200  1541106106796
# 1                                            Flat 55     200  1541106352796
# 2                       Quem Quiser Encontrar O Amor     200  1541106496796
# 3                                          Eriatarka     200  1541106673796
# 4                                    Becoming Insane     200  1541107053796
# 5                                    Congratulations     200  1541107493796
# 6                                         Once again     200  1541107734796
# 7                                            Pump It     200  1541108520796
# 8                     Nobody Puts Baby In The Corner     200  1541109125796
# 9   Mango Pickle Down River (With The Wilcannia Mob)     200  1541109325796
# 10                                  Eye Of The Tiger     200  1541110994796
#
#                                             userAgent  user_id   play_date  \
# 0   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...        8  2018-11-01
# 1   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...        8  2018-11-01
# 2   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...        8  2018-11-01
# 3   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...        8  2018-11-01
# 4   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...        8  2018-11-01
# 5   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...        8  2018-11-01
# 6   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...        8  2018-11-01
# 7   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...       10  2018-11-01
# 8   "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...       26  2018-11-01
# 9   "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...       26  2018-11-01
# 10  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...      101  2018-11-01
#
#            state
# 0             AZ
# 1             AZ
# 2             AZ
# 3             AZ
# 4             AZ
# 5             AZ
# 6             AZ
# 7    DC-VA-MD-WV
# 8             CA
# 9             CA
# 10            LA

# %%
#Seleccionar solo columnas relevantes
df_select = df[["artist",
                "first_name",
                "last_name",
                "gender",
                "length",
                "level",
                "location",
                "state",
                "song",
                "status",
                "play_date",
                "user_id"
              ]]

# %%
df_select
# Out:
#                         artist first_name last_name gender     length level  \
# 0                     Des''ree     Kaylee   Summers      F  246.30812  free
# 1                      Mr Oizo     Kaylee   Summers      F  144.03873  free
# 2                   Tamba Trio     Kaylee   Summers      F  177.18812  free
# 3               The Mars Volta     Kaylee   Summers      F  380.42077  free
# 4            Infected Mushroom     Kaylee   Summers      F  440.26730  free
# 5   Blue October / Imogen Heap     Kaylee   Summers      F  241.39710  free
# 6                    Girl Talk     Kaylee   Summers      F  160.15628  free
# 7              Black Eyed Peas     Sylvie      Cruz      F  214.93506  free
# 8                 Fall Out Boy       Ryan     Smith      M  200.72444  free
# 9                       M.I.A.       Ryan     Smith      M  233.71710  free
# 10                    Survivor     Jayden       Fox      M  245.36771  free
#
#                            location         state  \
# 0           Phoenix-Mesa-Scottsdale            AZ
# 1           Phoenix-Mesa-Scottsdale            AZ
# 2           Phoenix-Mesa-Scottsdale            AZ
# 3           Phoenix-Mesa-Scottsdale            AZ
# 4           Phoenix-Mesa-Scottsdale            AZ
# 5           Phoenix-Mesa-Scottsdale            AZ
# 6           Phoenix-Mesa-Scottsdale            AZ
# 7   Washington-Arlington-Alexandria   DC-VA-MD-WV
# 8    San Jose-Sunnyvale-Santa Clara            CA
# 9    San Jose-Sunnyvale-Santa Clara            CA
# 10             New Orleans-Metairie            LA
#
#                                                 song  status   play_date  \
# 0                                       You Gotta Be     200  2018-11-01
# 1                                            Flat 55     200  2018-11-01
# 2                       Quem Quiser Encontrar O Amor     200  2018-11-01
# 3                                          Eriatarka     200  2018-11-01
# 4                                    Becoming Insane     200  2018-11-01
# 5                                    Congratulations     200  2018-11-01
# 6                                         Once again     200  2018-11-01
# 7                                            Pump It     200  2018-11-01
# 8                     Nobody Puts Baby In The Corner     200  2018-11-01
# 9   Mango Pickle Down River (With The Wilcannia Mob)     200  2018-11-01
# 10                                  Eye Of The Tiger     200  2018-11-01
#
#     user_id
# 0         8
# 1         8
# 2         8
# 3         8
# 4         8
# 5         8
# 6         8
# 7        10
# 8        26
# 9        26
# 10      101

# %% [markdown]
# ### Crear conexión a Postgres

# %%
conn = psycopg2.connect("host={} dbname={} user={} password={} port={}".format(*config['CLUSTER'].values()))
cur = conn.cursor()

# %% [markdown]
# ### Crear tabla

# %%
play_events_table_drop = "DROP TABLE IF EXISTS public.play_events_acc"

# %%
cur.execute(play_events_table_drop)
conn.commit()

# %%
play_events_table_create= ("""CREATE TABLE IF NOT EXISTS public.play_events_acc(
                        artist          VARCHAR,
                        first_name      VARCHAR,
                        last_name       VARCHAR,
                        gender          VARCHAR,
                        length          FLOAT,
                        level           VARCHAR,
                        location        VARCHAR,
                        state           VARCHAR,
                        song            VARCHAR,
                        status          INT,
                        play_date       DATE,
                        user_id         INT
                        )""")

# %%
cur.execute(play_events_table_create)
conn.commit()

# %% [markdown]
# ### Cargar datos a tabla (Método 1)

# %%
columns = list(df_select.keys())

# %%
columns
# Out:
# ['artist',
#  'first_name',
#  'last_name',
#  'gender',
#  'length',
#  'level',
#  'location',
#  'state',
#  'song',
#  'status',
#  'play_date',
#  'user_id']

# %%
col_str = ','.join(columns)

# %%
val_str = "VALUES ({});"

# %%
for i,row in df_select.astype(str).iterrows():
    values = "'" + "','".join(row) + "'"
    sql_string = "INSERT INTO public.play_events_acc({}) ".format(col_str) + val_str.format(values)
    cur.execute(sql_string)

# %%
conn.commit()

# %% [markdown]
# ### Cargar datos a tabla (Método 2)

# %%
sql_string = "INSERT INTO public.play_events_acc(artist,first_name,last_name,gender,length,level,location,state,song,status,play_date,user_id) VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);"

# %%
cur.executemany(sql_string, df_select.values.tolist())

# %%
conn.commit()

# %% [markdown]
# ### Cargar datos a tabla (Método 3)

# %%
import sqlalchemy
import pyodbc

# %%
engine = sqlalchemy.create_engine('postgresql+psycopg2://postgres:Welcome1@database-1.cyeh2tknwf6x.us-east-1.rds.amazonaws.com:5432/postgres')

# %%
engine = sqlalchemy.create_engine("postgresql://postgres:Welcome1@localhost:5432/postgres")

# %%
df_select.to_sql("play_events_acc", engine, if_exists='append', index=False)

# %% [markdown]
# ### Consultar tabla

# %%
cur.execute("""SELECT * from public.play_events_acc""")

# %%
data_frame = pd.read_sql_query('SELECT * FROM public.play_events_acc;', conn)

# %%
data_frame.head(5)
# Out:
#               artist first_name last_name gender     length level  \
# 0            Des'ree     Kaylee   Summers      F  246.30812  free
# 1            Mr Oizo     Kaylee   Summers      F  144.03873  free
# 2         Tamba Trio     Kaylee   Summers      F  177.18812  free
# 3     The Mars Volta     Kaylee   Summers      F  380.42077  free
# 4  Infected Mushroom     Kaylee   Summers      F  440.26730  free
#
#                   location state                          song  status  \
# 0  Phoenix-Mesa-Scottsdale    AZ                  You Gotta Be     200
# 1  Phoenix-Mesa-Scottsdale    AZ                       Flat 55     200
# 2  Phoenix-Mesa-Scottsdale    AZ  Quem Quiser Encontrar O Amor     200
# 3  Phoenix-Mesa-Scottsdale    AZ                     Eriatarka     200
# 4  Phoenix-Mesa-Scottsdale    AZ               Becoming Insane     200
#
#     play_date  user_id
# 0  2018-11-01        8
# 1  2018-11-01        8
# 2  2018-11-01        8
# 3  2018-11-01        8
# 4  2018-11-01        8

# %%
data_frame.shape
# Out:
# (33, 12)

# %%
conn.close()
